# %% [markdown]
# ## Load Data
# Data's description here: https://github.com/owid/covid-19-data/tree/master/public/data

# %%
# Import package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Read data
file_name = "https://covid.ourworldindata.org/data/owid-covid-data.csv"
df = pd.read_csv("covid19_data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
df = df[df['location'] == "United States"]
df.head()
# Out:
#        iso_code      continent       location        date  total_cases  \
# 110270      USA  North America  United States  2020-01-22          1.0
# 110271      USA  North America  United States  2020-01-23          1.0
# 110272      USA  North America  United States  2020-01-24          2.0
# 110273      USA  North America  United States  2020-01-25          2.0
# 110274      USA  North America  United States  2020-01-26          5.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 110270        NaN                 NaN           NaN         NaN
# 110271        0.0                 NaN           NaN         NaN
# 110272        1.0                 NaN           NaN         NaN
# 110273        0.0                 NaN           NaN         NaN
# 110274        3.0                 NaN           NaN         NaN
#
#         new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 110270                  NaN  ...              1.2                151.089
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 110270 to 110869
# Data columns (total 62 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               600 non-null    object
#  1   continent                              600 non-null    object
#  2   location                               600 non-null    object
#  3   date                                   600 non-null    object
#  4   total_cases                            600 non-null    float64
#  5   new_cases                              599 non-null    float64
#  6   new_cases_smoothed                     594 non-null    float64
#  7   total_deaths                           562 non-null    float64
#  8   new_deaths                             562 non-null    float64
#  9   new_deaths_smoothed                    594 non-null    float64
# ...

# %%
df=df.fillna(0)

# %%
attributes = [ 
       'new_cases_smoothed',
       'new_deaths_smoothed', 'reproduction_rate', 'icu_patients','hosp_patients',
       'weekly_icu_admissions',
       'weekly_hosp_admissions','new_tests',
       'positive_rate','total_vaccinations',
       'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
       'new_vaccinations',
       'people_vaccinated_per_hundred',
       'stringency_index',
       'population_density', 'median_age', 'aged_65_older',
       'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy', 'human_development_index', 'excess_mortality']

# %%
df = df.set_index('date')

# %%
df.head()
# Out:
#            iso_code      continent       location  total_cases  new_cases  \
# date
# 2020-01-22      USA  North America  United States          1.0        0.0
# 2020-01-23      USA  North America  United States          1.0        0.0
# 2020-01-24      USA  North America  United States          2.0        1.0
# 2020-01-25      USA  North America  United States          2.0        0.0
# 2020-01-26      USA  North America  United States          5.0        3.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-01-22                 0.0           0.0         0.0                  0.0
# 2020-01-23                 0.0           0.0         0.0                  0.0
# 2020-01-24                 0.0           0.0         0.0                  0.0
# 2020-01-25                 0.0           0.0         0.0                  0.0
# 2020-01-26                 0.0           0.0         0.0                  0.0
#
# ...

# %%
df = df[attributes]
df.head()
# Out:
#             new_cases_smoothed  new_deaths_smoothed  reproduction_rate  \
# date
# 2020-01-22                 0.0                  0.0                0.0
# 2020-01-23                 0.0                  0.0                0.0
# 2020-01-24                 0.0                  0.0                0.0
# 2020-01-25                 0.0                  0.0                0.0
# 2020-01-26                 0.0                  0.0                0.0
#
#             icu_patients  hosp_patients  weekly_icu_admissions  \
# date
# 2020-01-22           0.0            0.0                    0.0
# 2020-01-23           0.0            0.0                    0.0
# 2020-01-24           0.0            0.0                    0.0
# 2020-01-25           0.0            0.0                    0.0
# 2020-01-26           0.0            0.0                    0.0
#
#             weekly_hosp_admissions  new_tests  positive_rate  \
# date
# 2020-01-22                     0.0        0.0            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, 2020-01-22 to 2021-09-12
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   new_cases_smoothed             600 non-null    float64
#  1   new_deaths_smoothed            600 non-null    float64
#  2   reproduction_rate              600 non-null    float64
#  3   icu_patients                   600 non-null    float64
#  4   hosp_patients                  600 non-null    float64
#  5   weekly_icu_admissions          600 non-null    float64
#  6   weekly_hosp_admissions         600 non-null    float64
#  7   new_tests                      600 non-null    float64
#  8   positive_rate                  600 non-null    float64
#  9   total_vaccinations             600 non-null    float64
#  10  people_vaccinated              600 non-null    float64
#  11  people_fully_vaccinated        600 non-null    float64
# ...

# %%
corr_matrix = df.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Heatmap
plt.figure(figsize=(25,20))
cmap = sns.diverging_palette(220,10,as_cmap = True)

# Deep dive into diverging_pattern
sns.heatmap(corr_matrix, xticklabels=corr_matrix.columns.values,
            yticklabels=corr_matrix.columns.values, cmap=cmap, vmax=1, center=0,
            square=True, linewidth= 0.5,
            cbar_kws={"shrink":0.82}, annot=True)
plt.title("Heatmap of Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Heatmap of Correlation Matrix')

# %%
attributes = [ 
       'new_cases_smoothed',
       'new_deaths_smoothed', 'reproduction_rate', 'icu_patients','hosp_patients',
       'weekly_icu_admissions',
       'weekly_hosp_admissions','new_tests',
       'positive_rate','total_vaccinations',
       'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
       'new_vaccinations',
       'people_vaccinated_per_hundred',
       'stringency_index',
       'excess_mortality']

# %%
df = df[attributes]

# %%
corr_matrix = df.corr()

# %%
# Heatmap
plt.figure(figsize=(20,20))
cmap = sns.diverging_palette(220,10,as_cmap = True)

# Deep dive into diverging_pattern
sns.heatmap(corr_matrix, xticklabels=corr_matrix.columns.values,
            yticklabels=corr_matrix.columns.values, cmap=cmap, vmax=1, center=0,
            square=True, linewidth= 0.5,
            cbar_kws={"shrink":0.82}, annot=True)
plt.title("Heatmap of Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Heatmap of Correlation Matrix')

# %%
corr_matrix["new_cases_smoothed"].sort_values(ascending=False)
# Out:
# new_cases_smoothed               1.000000
# hosp_patients                    0.960756
# icu_patients                     0.935855
# new_deaths_smoothed              0.736970
# new_tests                        0.729908
# positive_rate                    0.545196
# stringency_index                 0.340772
# weekly_hosp_admissions           0.263073
# excess_mortality                 0.132580
# new_vaccinations                 0.023476
# people_vaccinated               -0.010783
# people_vaccinated_per_hundred   -0.010784
# total_vaccinations              -0.013113
# people_fully_vaccinated         -0.018294
# reproduction_rate               -0.033658
# weekly_icu_admissions                 NaN
# total_boosters                        NaN
# Name: new_cases_smoothed, dtype: float64

# %%
corr_matrix["new_deaths_smoothed"].sort_values(ascending=False)
# Out:
# new_deaths_smoothed              1.000000
# new_cases_smoothed               0.736970
# hosp_patients                    0.685168
# icu_patients                     0.650558
# positive_rate                    0.641639
# stringency_index                 0.529915
# new_tests                        0.513949
# excess_mortality                 0.196261
# weekly_hosp_admissions           0.181400
# new_vaccinations                 0.047458
# reproduction_rate               -0.127273
# people_vaccinated               -0.264962
# people_vaccinated_per_hundred   -0.264963
# total_vaccinations              -0.278555
# people_fully_vaccinated         -0.298569
# weekly_icu_admissions                 NaN
# total_boosters                        NaN
# Name: new_deaths_smoothed, dtype: float64

# %%
# Explain columns data
# new_cases_smoothed :
# new_deaths_smoothed:
# hosp_patients:
# icu_patients:
# positive_rate:
# stringency_index
# new_test:

# %%
# from pandas.tools.plotting import scatter_matrix # for older version of pandas

from pandas.plotting import scatter_matrix

col = ['new_cases_smoothed','new_deaths_smoothed','icu_patients','hosp_patients','new_tests',
       'positive_rate','stringency_index',]

scatter_matrix(df[col], figsize=(20,20))
plt.show()

# %% [markdown]
# # Prepare data for Linear Regression model

# %%
df = df[col]
df.tail()
# Out:
#             new_cases_smoothed  new_deaths_smoothed  icu_patients  \
# date
# 2021-09-08          151507.857             1491.857       25978.0
# 2021-09-09          150356.143             1539.714       25867.0
# 2021-09-10          144801.143             1602.286       25593.0
# 2021-09-11          144994.714             1626.286       25007.0
# 2021-09-12          144315.571             1614.000       24931.0
#
#             hosp_patients  new_tests  positive_rate  stringency_index
# date
# 2021-09-08        96335.0        0.0            0.0               0.0
# 2021-09-09        95591.0        0.0            0.0               0.0
# 2021-09-10        94334.0        0.0            0.0               0.0
# 2021-09-11        91449.0        0.0            0.0               0.0
# 2021-09-12        91109.0        0.0            0.0               0.0

# %%
x_cases = df.iloc[:,1:].values
y_cases = df.iloc[:,0].values

# %%
x_cases.shape
# Out:
# (600, 6)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X_train, X_test, Y_train, Y_test = train_test_split(x_cases, y_cases, test_size =0.2, random_state=0)

regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = regressor.predict(X_test)

# %%
Y_mse = mean_squared_error(Y_test, Y_predict)
Y_mse
# Out:
# 175307287.4357705

# %%
Trial = np.array([1614,24931,91109,0,0,0])
Trial = Trial.reshape((-1,6))

# %%
regressor.predict(Trial)[0]
# Out:
# 105949.76508186119

# %%
regressor.coef_
# Out:
# array([-1.17602548e+00, -8.47191467e+00,  3.53531264e+00,  2.92324721e-03,
#         1.66552452e+05,  1.19458864e+02])

# %%
regressor.intercept_
# Out:
# -3037.6242509198346

# %%
plt.scatter(x=df.index, y= df['new_cases_smoothed'])
plt.show()

# %%
pd.DataFrame({'y': Y_test,'y_predict': Y_predict})
# Out:
#               y      y_predict
# 0     64065.143   69597.530771
# 1     22142.857   14351.611594
# 2     41087.000   44634.356999
# 3     33843.714   40261.003868
# 4     52600.429   51979.054942
# ..          ...            ...
# 115   21322.571   12503.916293
# 116  102154.143  115889.687391
# 117   64710.714   66424.925621
# 118  162245.000  170928.659728
# 119   43780.000   52284.927338
#
# [120 rows x 2 columns]
